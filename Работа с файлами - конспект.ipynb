# %% [markdown]
# # Работа с файлами

# %% [markdown]
# ## Функция open(name, regime, encoding)

# %% [markdown]
# Функция open позволяет открывать/создавать различные файлы
#
# Режимы доступа:
# - 'r' - только для чтения
# - 'w' - для записи (СОТРЕТ ФАЙЛ ЕСЛИ ОН УЖЕ ЕСТЬ!)
# - 'a' - для записи, добавляет новые данные в конец файла
# - 'r+' - чтение и запись, для перезаписи части содержимого файла
# - 'x' - создать новый файл (ВЫЗОВЕТ ОШИБКУ ЕСЛИ ФАЙЛ УЖЕ ЕСТЬ)
#
# По умолчанию (без второй переменной) файл будет открыт для чтения

# %% [markdown]
# Когда мы открываем некий файл, переменная не станет содержимым файла, но ссылкой на него:

# %%
std = open('C:\\Users\\Пользователь\\Desktop\\std.txt', 'w')

# %% [markdown]
# Мы используем двойной слэш чтобы подчеркнуть, что нам нужен именно слэш, а не какая-то другая команда.
#
# Можно обойтись и без него с помощью r-выражения:

# %%
alpha1 = open(r'C:\Users\Пользователь\Desktop\alpha.txt')

# %% [markdown]
# Также в raw-выражениях можно обойтись и прямым слешэм:

# %%
alpha2 = open(r'C:/Users/Пользователь/Desktop/alpha.txt')

# %% [markdown]
# Такой простой способ сработает, только если в файле латиница и цифры.
#
# Чтобы кодировка не поехала, нужно дополнительно указывать параметр encoding в функции open():

# %%
alpha = open(r'C:/Users/Пользователь/Desktop/alpha.txt', encoding='utf-8')

# %%
print(std.encoding)
print(alpha.encoding)
# Out:
# cp1251
# utf-8

# %% [markdown]
# ## Чтение файлов

# %% [markdown]
# Для чтения файлов используются 3 файловых метода:
# - read() - читает все содержимое
# - readline() - читает одну строку из файла
# - readlines() - читает все содержимое файла и возвращает список строк

# %% [markdown]
# ## Метод read()

# %% [markdown]
# Метод read() считывает все содержимое из файла и возвращает строку с символами перехода на новую:

# %%
lang = open('languages.txt')

# %%
lang_content = lang.read()
print(lang_content)
# Out:
# a
# Javascript
# C#
# C
# C++
# PHP
# R
# Objective-C

# %% [markdown]
# А если передать методу целочисленный параметр - можно ограничить кол-во считываемых символов

# %%
lang_head = lang.read(10)
print(lang_head)

# %% [markdown]
# ## Метод readline()

# %% [markdown]
# Метод readline() считывает одну строку из файла (всю строку до символа \n):

# %%
lang = open('languages.txt')

# %%
print(lang.readline())
lang.close()
# Out:
# Python

# %%
lang = open('languages.txt')

# %%
for line in lang:
    print(line)
# Out:
# Python
#
# Java
#
# Javascript
#
# C#
#
# C
#
# C++
#
# PHP
#
# R
#
# Objective-C

# %% [markdown]
# ## Метод readlines()

# %% [markdown]
# Метод readlines() считывает все строки из файла и возвращает список из строк файла:

# %%
lang = open('languages.txt')

# %%
langs = lang.readlines()
print(langs)
# Out:
# ['Python\n', 'Java\n', 'Javascript\n', 'C#\n', 'C\n', 'C++\n', 'PHP\n', 'R\n', 'Objective-C']

# %% [markdown]
# Избавимся от символа переноса строки:

# %%
langs = [el.strip() for el in langs]
print(langs)
# Out:
# ['Python', 'Java', 'Javascript', 'C#', 'C', 'C++', 'PHP', 'R', 'Objective-C']

# %% [markdown]
# ## Метод splitlines()

# %% [markdown]
# А еще можно воспользоваться методом __read()__ в связке с __splitlines()__ чтобы разбить текст на строки без символа переноса строки:

# %%
lang.close()
lang = open('languages.txt')
langs = lang.read().splitlines()
langs
# Out:
# ['Python', 'Java', 'Javascript', 'C#', 'C', 'C++', 'PHP', 'R', 'Objective-C']

# %% [markdown]
# ## Метод .close()

# %% [markdown]
# Метод .close() позволяет сохранить и закрыть файл для завершения работы с ним:

# %%
alpha.close()

# %% [markdown]
# Для проверки закрыт ли файл можно использовать атрибут .closed:

# %%
print(alpha.closed)
print(std.closed)
# Out:
# True
# False

# %% [markdown]
# А еще можно получить режим доступа и имя файла:

# %%
print(std.mode)
print(std.name)
# Out:
# w
# C:\Users\Пользователь\Desktop\std.txt

# %% [markdown]
# ## Текущая позиция в файле (курсор/каретка)

# %% [markdown]
# При чтении файла целиком происходит следующее: курсор пробегает по всем символам и из начала файла (стандартная позиция 0) "добегает" до конца.
# При этом повторный вызов методов read/readlines уже ничего не сделает - поскольку курсору некуда бежать

# %% [markdown]
# Для повторного чтения данных можно переоткрыть файл, либо переместить курсор с помощью метода seek()

# %% [markdown]
# ## Метод seek()

# %% [markdown]
# Метод seek() принимает в качестве аргумента кол-во байт от начала файла, на которое нужно поставить курсор.
#
# Для перехода в начало файла методу надо передать аргумент "0":

# %%
file = open('prices.txt', encoding='utf-8')
print(file.read())
# Out:
# телефон	4	12500
# бургер	1	500
# курс	1	1400
# подписка	40	9500
# наушники	2	22450
# телефон	2	2500
# ноутбук	5	155000
# диван	100	300

# %%
file.seek(0)
print(file.readline())
file.seek(8)
print(file.readline())
# Out:
# телефон	4	12500
#
# фон	4	12500

# %% [markdown]
# ## Метод tell()

# %% [markdown]
# Метод tell() возвращает текущее местоположение каретки:

# %%
print(file.tell())
file.seek(0)
print(file.tell())
# Out:
# 24
# 0

# %% [markdown]
# ## Менеджер контекста

# %% [markdown]
# Важно своевременно закрывать файлы с помощью метода close(). Закрытие файлов вручную, а также отдача закрытия на откуп среде исполнения, обладают существенным недостатком: если между открытием файла и его закрытием произойдёт ошибка, в лучшем случае файл окажется открыт слишком долго, а в худшем случае часть данных не сохранится.

# %% [markdown]
# Для того чтобы иметь возможность автоматически закрывать файл сразу после окончания работы с ним файл нужно использовать как менеджер контекста:

# %%
with object as name:
    # Здесь нам доступен ресурс name.
    # Это тело with-блока.
# А здесь ресурс name уже освобождён, даже если в теле with-блока произошла ошибка.
# Out:
#   File "C:\Users\73B5~1\AppData\Local\Temp/ipykernel_35628/811538803.py", line 4
#     # А здесь ресурс name уже освобождён, даже если в теле with-блока произошла ошибка.
#                                                                                        ^
# IndentationError: expected an indented block

# %% [markdown]
# Синтаксис - выше
#
# В целом же работает это так: как только закончится код, оформленный с отступами в *with* "контекст" закончится и Питон закроет файл

# %% [markdown]
# Код по чтению файла 'prices.txt' можно переписать так:

# %%
with open('prices.txt', encoding='utf-8') as file:
    for line in file:
        print(line)
# Out:
# телефон	4	12500
#
# бургер	1	500
#
# курс	1	1400
#
# подписка	40	9500
#
# наушники	2	22450
#
# телефон	2	2500
#
# ноутбук	5	155000
#
# диван	100	300

# %%
with open('numbers.txt', encoding='utf-8') as file:
    lst = [l.split() for l in file.readlines()]
    file.seek(0)
    s = file.read()
    print(s)
    print(type(s))
# Out:
#   67 89         100
# 78
#   90 7 8 9
#  1 2 3 4   5
#     90 0       999
#
# <class 'str'>

# %% [markdown]
# # Запись данных в файлы

# %% [markdown]
# Для записи используются 2 файловых метода:
# - write() - записывает переданную строку в файл
# - writelines() - записывает переданный список строк в файл

# %% [markdown]
# ## write()

# %% [markdown]
# Общий формат применения файлового метода write():
#
# файловая_переменная.writе(строковое_значение)
#
# Вид записи зависит от режима открытия файла

# %% [markdown]
# Если файл открыт для записи - прочитать его нельзя:

# %%
with open('std.txt','w', encoding='utf-8') as file:
    s = file.read()
    print(s)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# C:\Users\73B5~1\AppData\Local\Temp/ipykernel_35628/1142527347.py in <module>
#       1 with open('std.txt','w', encoding='utf-8') as file:
# ----> 2     s = file.read()
#       3     print(s)
#
# UnsupportedOperation: not readable

# %%
with open('std.txt','w', encoding='utf-8') as file:
    file.write('Я богатый\n')
    file.write('Я красивый\n')
    print(s)
# Out:
# Я богатый
# Я красивый

# %%
with open('std.txt','a', encoding='utf-8') as file:
    file.write('Я крутой\n')

# %%
with open('std.txt','r', encoding='utf-8') as file:
    s = file.read()
    print(s)
# Out:
# Я богатый
# Я красивый
# Я крутой
# Я крутой

# %% [markdown]
# ## writelines()

# %% [markdown]
# В метод writelines() нужно передавать список строк, который необходимо записать:

# %%
with open('philosophers.txt','w', encoding='utf-8') as file:
    file.writelines(['Серен Кьеркегор\n', 'Фридрих Ницше\n'])

# %%
with open('philosophers.txt', encoding='utf-8') as file:
    s = file.read()
    print(s)
# Out:
# Серен Кьеркегор
# Фридрих Ницше

# %% [markdown]
# ## Запись при помощи print()

# %% [markdown]
# Для записи данных можно использовать функцию print(), но для этого ей надо передать именованный аргумент *file*:

# %%
with open('philosophers.txt', 'a', encoding='utf-8') as file1:
    print('Зигмунд Фрейд\n', file=file1)

# %%
with open('philosophers.txt', encoding='utf-8') as file:
    s = file.read()
    print(s)
# Out:
# Серен Кьеркегор
# Фридрих Ницше
# Зигмунд Фрейд

# %% [markdown]
# ## Библиотека os

# %% [markdown]
# Библиотека os предлагает набор инструментов для работы с файловой системой ОС

# %% [markdown]
# ### listdir()

# %% [markdown]
# __listdir()__ позволяет вывести на экран имена объектов в той или иной папке.
# Если не передать аргумент - выведет все имеющиеся объекты

# %%
import os
import os.path
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'answer.txt', 'class_scores.txt', 'data.txt', 'dataset_24465_4.txt', 'encrypted.bin', 'file.txt', 'forbidden_words.txt', 'goats.txt', 'input.txt', 'languages.txt', 'loggable.py', 'loggable_Copy1.py', 'new_scores.txt', 'numbers.txt', 'nums.txt', 'output.txt', 'passwords.txt', 'philosophers.txt', 'population.txt', 'prices.txt', 'res.txt', 'sentences.txt', 'std.txt', 'stepik.txt', 'words.txt', '__pycache__', 'Итераторы и генераторы.ipynb', 'Классы - конспект.ipynb', 'Машинное обучение - общее.ipynb', 'Методы множеств - конспект.ipynb', 'Модули decimal и fractions.ipynb', 'Модули и импорт.ipynb', 'Модуль random - конспект.ipynb', 'Модуль time - конспект.ipynb', 'Отладочная.ipynb', 'Ошибки и исключения.ipynb', 'Работа с файлами - конспект.ipynb', 'Работа со списками - конспект.ipynb', 'Словари - конспект.ipynb', 'Строки - конспект.ipynb', 'Тип complex, модули complex и cmath.ipynb', 'Функции.ipynb']

# %%
print(os.listdir('C:\\Users\\Пользователь\\Desktop\\Статистика по подбору'))
# Out:
# ['Воронка по подбору hh 2018(новая) .xlsx', 'Воронка по подбору hh 2018.xlsx', 'Воронка по подбору hh 2019(новая).xlsx', 'Воронка по подбору hh 2019.xlsx', 'Воронка по подбору Активный поиск 2018.xlsx', 'Воронка по подбору Активный поиск 2019 (yjdfz).xlsx', 'Воронка по подбору Активный поиск 2019.xlsx', 'Клиентская база.xlsx', 'Конверсия по первичным собеседованиям (дни недели) 2018.xlsx', 'Конверсия по первичным собеседованиям (дни недели) 2019.xlsx', 'Март.xlsx', 'Направления на работу 2013-2019.xlsx', 'Отказы СБ.xlsx', 'Отчет по вакансиям hh.ru', 'Отчет по отказам 2018-2019.xlsx', 'Подбор 2017-2019.xlsx', 'Просмотры и отклики hh.ru по дням недели 2018.xlsx', 'Просмотры и отклики hh.ru по дням недели 2019.xlsx', 'Результаты работы за полгода.xlsx', 'Увольнения 2018-2019.xlsx', 'Янв-Фев.xlsx']

# %% [markdown]
# ### getcwd()

# %% [markdown]
# __getcwd()__ позволяет получить путь до текущей директории, в которой исполняется код:

# %%
print(os.getcwd())
# Out:
# C:\Users\Пользователь\Конспекты

# %% [markdown]
# ### getcwd()

# %% [markdown]
# __getcwd()__ позволяет получить путь до текущей директории, в которой исполняется код:

# %%
print(os.getcwd())
# Out:
# C:\Users\Пользователь\Конспекты

# %% [markdown]
# ### exists()

# %% [markdown]
# __os.path.exists('filename.py')__ позволяет проверить, существует ли файл или папка в текущей директории:

# %%
print(os.path.exists('res.txt'))
print(os.path.exists('Pitonist'))
# Out:
# True
# False

# %% [markdown]
# ### isfile() и isdir()

# %% [markdown]
# Методы __os.path__ isfile() и isdir() позволяет проверить, является ли файлом или папкой некий объект:

# %%
print(os.path.isdir('C:\\Users\\Пользователь\\Конспекты'))
print(os.path.isfile('Работа с файлами - конспект.ipynb'))
# Out:
# True
# True

# %% [markdown]
# ### abspath()

# %% [markdown]
# Метод __os.path.abspath()__ возвращает полный путь к файлу:

# %%
print(os.path.abspath('Работа с файлами - конспект.ipynb'))
# Out:
# C:\Users\Пользователь\Конспекты\Работа с файлами - конспект.ipynb

# %%
print(os.path.basename('Работа с файлами - конспект.ipynb'))
# Out:
# Работа с файлами - конспект.ipynb

# %% [markdown]
# ### chdir()

# %% [markdown]
# Метод __chdir()__ позволяет сменить текущую папку для интерпретатора

# %%
os.chdir('C:\\Users\\Пользователь\\Конспекты')
print(os.getcwd())
os.chdir('C:\\Program Files')
print(os.getcwd())
# Out:
# C:\Users\Пользователь\Конспекты
# C:\Program Files

# %% [markdown]
# ### walk()

# %% [markdown]
# Метод __walk()__ позволяет рекурсивно пройти по всем папкам в текущей директории, и вывести список всех их подфайлов и подпапок:

# %%
os.chdir('C:\\Users\\Пользователь\\Desktop')
print(os.getcwd())
for current_dir, dirs, files in os.walk('.'):   # точку передаем в качестве аргумента, чтобы начать с текущей директории
    print(current_dir, dirs, files, sep = '\n')
    print()
    print()
# Out:
# C:\Users\Пользователь\Desktop
# .
# ['.ipynb_checkpoints', '9785977567312add1', 'bluescreenview', 'Coursera', 'data-science-from-scratch-master', 'DRAM-Calculator-for-Ryzen-1.7.3', 'drive-download-20190126T214701Z-001', 'HR', 'hr connect', 'Know-How', 'Python', 'Setup', 'thphn163', 'Victoria528', '_17e8313e80520da7c04cfe8307d468f1_vector_operations', 'Архив (2)', 'Казань', 'Статистика по подбору', 'Творчество']
# ['525.jpg', 'ABBYY FineReader 14.lnk', 'Age of Gladiators.url', 'AIDA64 Extreme.lnk', 'alpha.txt', 'AnyDesk.exe', 'Assassins Creed Odyssey.lnk', 'cc_20211107_173237.reg', 'Cemu — ярлык.lnk', 'Core Temp.lnk', 'Days Gone.lnk', 'desktop.ini', 'Dying Light.url', 'Gears Tactics.url', 'Hades.url', 'Hardspace Shipbreaker.url', 'Immortals Fenyx Rising.lnk', 'Kingdom Come Deliverance.url', 'Microsoft Teams.lnk', 'Middle-earth™ Shadow of War™.url', 'Minecraft.lnk', 'Mount & Blade II Bannerlord.url', 'Nioh Complete Edition.url', 'rvn-pool — ярлык.lnk', 'SAVEDATA.BIN', 'Sekiro Shadows Die Twice.lnk', 'SpeedFan.lnk', 'std.txt', 'Subnautica.url', 'Telegram.lnk', 'The Elder Scrolls V Skyrim Special Edition.url', 'Totally Accurate Battle Simulator.url', 'WhatsApp.lnk', '~$Копия Актуальный доход 2021.xlsx', '~$кумент Microsoft Word (2).docx', '~$кумент Microsoft Word.docx', 'Автореферат диссертация Захаров Н.В..docx', 'Аналитический отчет.xlsx', 'Архив (2).zip', 'верх фона1.PNG', 'ВКР Захаров Н.В. антиплагиат.docx', 'ДДС Мир Дверей.xlsx', 'Диссер.docx', 'Документ Microsoft Word (2).docx', 'Документ Microsoft Word (3).docx', 'Документ Microsoft Word.docx', 'Кассир.txt', 'Копия 2020-06-25 - ЗНАНИЯ, КОНТРОЛЬ, ОТВЕТСТВЕННОСТЬ.jpg', 'Копия Актуальный доход 2021.xlsx', 'Лист Microsoft Excel (2).xlsx', 'Лист Microsoft Excel.xlsx', 'Личные расходы_.xlsx', 'Логотип Новый.png', 'Магистерская диссертация Захаров Н.В..docx', 'Новый текстовый документ.txt', 'Отзыв_Захаров Н.В.docx', 'ПК.txt', 'план мероприятий.xlsx', 'Презентация Microsoft PowerPoint.pptx', 'Презентация ВКР Захаров Н.В..pptx', 'Работник торгового зала.txt', 'Ракета.PNG', 'Рецензия Магистерская диссертация Захаров Н.В..doc', 'скрин.png', 'Скрин1.jpg', 'Скрин2.jpg', 'Скрин3.jpg', 'скрин555.png', 'Скрипт ТИ.docx', 'Снимок.PNG', 'Структура департамента по работе с персоналом.PNG', 'Текст выступления 1.docx', 'Текст выступления.docx', 'Фон оригинал.jpg', 'Фон широкоформат, без лого.png', 'Фон широкоформат.jpg', 'Эссе.docx']
#
#
# .\.ipynb_checkpoints
# []
# []
#
#
# .\9785977567312add1
# []
# ['9785977567312add1.txt']
#
#
# .\bluescreenview
# []
# ['BlueScreenView.chm', 'BlueScreenView.exe', 'readme.txt']
#
#
# .\Coursera
# []
# ['Screenshot_1.png', 'Screenshot_2.png']
#
#
# .\data-science-from-scratch-master
# ['data-science-from-scratch-master']
# []
#
#
# .\data-science-from-scratch-master\data-science-from-scratch-master
# ['first-edition', 'im', 'scratch']
# ['.gitignore', 'comma_delimited_stock_prices.csv', 'INSTALL.md', 'LICENSE', 'links.md', 'README.md', 'requirements.txt', 'stocks.csv']
#
#
# .\data-science-from-scratch-master\data-science-from-scratch-master\first-edition
# ['code', 'code-python3']
# ['README.md']
#
#
# .\data-science-from-scratch-master\data-science-from-scratch-master\first-edition\code
# []
# ['charts.py', 'clustering.py', 'colon_delimited_stock_prices.txt', 'comma_delimited_stock_prices.csv', 'comma_delimited_stock_prices.txt', 'databases.py', 'decision_trees.py', 'egrep.py', 'getting_data.py', 'gradient_descent.py', 'hypothesis_and_inference.py', 'introduction.py', 'linear_algebra.py', 'line_count.py', 'logistic_regression.py', 'machine_learning.py', 'mapreduce.py', 'most_common_words.py', 'multiple_regression.py', 'naive_bayes.py', 'natural_language_processing.py', 'nearest_neighbors.py', 'network_analysis.py', 'neural_networks.py', 'plot_state_borders.py', 'probability.py', 'recommender_systems.py', 'simple_linear_regression.py', 'states.txt', 'statistics.py', 'stocks.txt', 'tab_delimited_stock_prices.txt', 'visualizing_data.py', 'working_with_data.py', '__init__.py']
#
#
# .\data-science-from-scratch-master\data-science-from-scratch-master\first-edition\code-python3
# []
# ['charts.py', 'clustering.py', 'colon_delimited_stock_prices.txt', 'comma_delimited_stock_prices.csv', 'comma_delimited_stock_prices.txt', 'databases.py', 'decision_trees.py', 'egrep.py', 'getting_data.py', 'gradient_descent.py', 'hypothesis_and_inference.py', 'introduction.py', 'linear_algebra.py', 'line_count.py', 'logistic_regression.py', 'machine_learning.py', 'mapreduce.py', 'most_common_words.py', 'multiple_regression.py', 'naive_bayes.py', 'natural_language_processing.py', 'nearest_neighbors.py', 'network_analysis.py', 'neural_networks.py', 'plot_state_borders.py', 'probability.py', 'README.md', 'recommender_systems.py', 'simple_linear_regression.py', 'states.txt', 'stats.py', 'stocks.txt', 'tab_delimited_stock_prices.txt', 'visualizing_data.py', 'working_with_data.py', '__init__.py']
#
#
# .\data-science-from-scratch-master\data-science-from-scratch-master\im
# []
# ['README.md']
#
#
# .\data-science-from-scratch-master\data-science-from-scratch-master\scratch
# []
# ['clustering.py', 'crash_course_in_python.py', 'databases.py', 'decision_trees.py', 'deep_learning.py', 'getting_data.py', 'gradient_descent.py', 'inference.py', 'introduction.py', 'k_nearest_neighbors.py', 'linear_algebra.py', 'logistic_regression.py', 'machine_learning.py', 'mapreduce.py', 'multiple_regression.py', 'naive_bayes.py', 'network_analysis.py', 'neural_networks.py', 'nlp.py', 'nlp_advanced.py', 'probability.py', 'recommender_systems.py', 'simple_linear_regression.py', 'statistics.py', 'visualization.py', 'working_with_data.py', '__init__.py']
#
#
# .\DRAM-Calculator-for-Ryzen-1.7.3
# ['en']
# ['CCXLatency.exe', 'HCIMemTestController.dll', 'LineLatency.exe', 'MemSpeed.exe', 'memtest.exe', 'MetroFramework.dll', 'RandomLatency.exe', 'Ryzen DRAM Calculator 1.7.3.exe', 'Ryzen DRAM Calculator 1.7.3.exe.config', 'WinRing0.dll', 'WinRing0.sys', 'WinRing0x64.dll', 'WinRing0x64.sys']
#
#
# .\DRAM-Calculator-for-Ryzen-1.7.3\en
# []
# ['Ryzen DRAM Calculator 1.7.3.resources.dll']
#
#
# .\drive-download-20190126T214701Z-001
# ['Аналитика', 'Всячина', 'Графики работы', 'Документооборот', 'ЗРС,ЗВС, планы, доклады', 'Описание работы Отделения Построения', 'Рабочие документы для РО2', 'Рабочие документы РО3', 'СЕРТИФИКАТ СООТВЕТСТВИЯ', 'Справочные материалы', 'ФП']
# ['2016-01-23 Программа подготовки к собранию персонала для ведущего.docx', '2016-01-23 Программа подготовки к собранию персонала для остальных РО.docx', '2016-01-23 Программа подготовки к собранию персонала для РО1.docx', '2018-09-27 Инструкция по формированию должностных папок.docx', 'movavi-screen-capture-studio-9.5.0-repack.zip', 'Пароли ро1.xlsx', 'Распорядок дня менеджера по персоналу.docx', 'РО1 Технология описания должности.docx', 'Томила АМПП.xlsx', 'Учет движения книг в компании.xlsx', 'Чек-лист посещения салона.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Аналитика
# []
# ['Планфакт месяц по подразделениям.xlsx', 'Планфакт недельный.xlsx', 'ФОТ.xlsx', 'Эффективность 07.2018.xlsx', 'Эффективность.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина
# ['Архив АА', 'ГСМ', 'Игра по ФП', 'Координации', 'ОДО ФОТООТЧЕТЫ ']
# ['ilovepdf_com-1-6.pdf', 'ilovepdf_com-11-16.pdf', 'ilovepdf_com-16-21.pdf', 'ilovepdf_com-21-27.pdf', 'ilovepdf_com-6-11.pdf', 'Апрель Ежедневные отчеты.xlsx', 'Вакансия _Курьер_.xlsx', 'ГСМ курьер.xlsx', 'ГСМ.xlsx', 'ДР.xlsx', 'Запись Елизаветинская.mp4', 'Копия прайс пакеты 01.06.18.xlsx', 'План продаж.xlsx', 'Ппф Приемная.m4a', 'презентация отчет Итоги за 2018 год.pptx', 'Статья_ _Как передать функцию_.docx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА
# ['Архив', 'Картинки для карты линз', 'Лед строка']
# ['5 тысяч .jpg', 'banknota-1000-rubley-proverka.jpg', 'а5_ПР-02.tif', 'Анкета для аренды.doc', 'Очки для дали.pdf', 'Примеры отчета оперативного.docx', 'Расписание рабочего дня в салоне оптики.docx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив
# ['Книги продуктов', 'Реклама', 'Скрипты', 'Чек-листы']
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\

#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Реклама\Стрелка
# ['Банер', 'Внутри']
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Реклама\Стрелка\Банер
# []
# ['Логотип и отбойник.jpg', 'Проба_205.jpg']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Реклама\Стрелка\Внутри
# []
# ['Отбойник.jpg']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Реклама\Фото для макетов
# ['Очки с резкостью']
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Реклама\Фото для макетов\Очки с резкостью
# []
# ['426813-Kycb Зеленый лес.jpg']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Скрипты
# []
# ['Стадии продаж и текст разговора корректированный.odt', 'Стадии продаж и текст разговора.docx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Чек-листы
# ['Офисы август 2017']
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Чек-листы\Офисы август 2017
# ['Анализ 07-08.08.17']
# ['Чек-лист(1).xlsx', 'Чек-лист.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Архив\Чек-листы\Офисы август 2017\Анализ 07-08.08.17
# []
# ['Чек-лист 07-08.08.17.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Картинки для карты линз
# []
# ['Антиблик.jpg', 'Индекс.jpg', 'Очки для дали.docx', 'Поляризация.jpg']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Архив АА\Лед строка
# []
# ['BXLED1.pj', 'LedshowTW-201616.06.06.00.rar', 'LedshowTW2016(16.06.06.00).exe']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\ГСМ
# []
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Игра по ФП
# []
# ['2015-10-13 М9. Игра по ФП. Отчет о выплатах по заявкам на выделение средств.xlsx', '2015-10-13 М9. Игра по ФП. Список заявок на выделение средств департамента.xlsx', '2015-10-13 М9. Игра по ФП. Справка о валовом доходе.xlsx', '2015-10-13 М9. Игра ФП Программа ФП №1.xlsx', '2015-10-13 М9. Игра ФП. Справка о счетах и фондах.xlsx', '2015-10-14 М9. Игра по ФП. Бланк плана по доходу.xlsx', '2015-11-02 М9 Регламент по ФП для игры.docx', '2018-12-27 М9. Игра по ФП. Директива по распределению средств.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Всячина\Координации
# []
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\ОДО ФОТООТЧЕТЫ
# ['Занятие №5']
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\ОДО ФОТООТЧЕТЫ \Занятие №5
# ['17.10.2018', '19.10.2018']
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\ОДО ФОТООТЧЕТЫ \Занятие №5\17.10.2018
# []
# []
#
#
# .\drive-download-20190126T214701Z-001\Всячина\ОДО ФОТООТЧЕТЫ \Занятие №5\19.10.2018
# []
# []
#
#
# .\drive-download-20190126T214701Z-001\Графики работы
# []
# ['График работы Афипский-1.xlsx', 'График работы Белореченск-1.xlsx', 'График работы Елизаветинская-1.xlsx', 'График работы Кореновск-1.xlsx', 'График работы Кореновск-2.xlsx', 'График работы Краснодар-1.xlsx', 'График работы Краснодар-2.xlsx', 'График работы Краснодар-3.xlsx', 'График работы Майкоп-1.xlsx', 'Новая таблица.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Документооборот
# ['Доверенности', 'Договоры', 'Должностные инструкции', 'Заявления', 'ЛНА (Приказы)', 'Учредительные документы']
# ['График отпусков на 2019.xlsx', 'Журнал регистрации приказов.docx', 'Инструкция для определения подлинности купюр.docx', 'Платежная ведомость (авто шаблон).xlsx', 'Справочник работников.xlsx', 'Страхование Тандер.xlsx', 'Тех схема обязанностей Товароведа откорректир.odt', 'ТУРВ АУП.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\
']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция письменных коммуникаций\БЛАНКИ ОБЩИЙ ДОСТУП\Для Планирования
# []
# ['2018-10-08 Шаблон плана на неделю руководителя отделения.docx', '2018-12-03 Бланк Дневник выполнения формул состояний.docx', 'Дневник выполнения формул состояний (пример).docx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция письменных коммуникаций\БЛАНКИ ОБЩИЙ ДОСТУП\Для Статистик
# []
# ['График статистик.docx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция письменных коммуникаций\БЛАНКИ ОБЩИЙ ДОСТУП\Для ФП
# []
# ['2018-11-20 Бланк Заявка на выделение средств.docx', '2018-12-27 Бланк Заказ на приобретение.docx', '2018-12-27 Бланк Заявка на обязательство.docx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция почтовых отправлений
# []
# ['Журнал входящей и исходящей корреспоненции.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция приемной
# ['РЕЖИМ РАБОТЫ']
# ['controlsites.xlsx', 'ГРАФИК РАБОТЫ В ПРАЗДНИЧНЫЕ ДНИ_.docx', 'Журнал регистрации звонков и входящих посетителей.xlsx', 'Задачи для Менеджера секции приемной.xlsx', 'Контакты.xlsx', 'Поставщики.xlsx', 'Скрипт для приема звонков и посетителей.docx', 'Список emailов.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция приемной\РЕЖИМ РАБОТЫ
# []
# []
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Секция электронных коммуникаций
# []
# ['Журнал регистрации сбоев в работе аппаратуры.xlsx', 'Пароли салоны.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО2\Статистика НО2
# []
# ['Таблица учета статистики НО2.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО3
# ['Секция инспекций', 'Секция поощрений', 'Секция рудиментов', 'Секция статистик']
# []
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО3\Секция инспекций
# []
# ['2018-10-08 Проверочный список для инспекции рабочего места.xlsx', 'Таблица нарушений (проект).xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО3\Секция поощрений
# []
# ['ЗП ТТ.xlsx', 'Калькулятор з_п.xlsx', 'Мотивация.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО3\Секция рудиментов
# []
# ['Рудименты.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Описание работы Отделения Построения\НО3\Секция статистик
# []
# ['Статистики.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Рабочие документы для РО2
# []
# ['Апрель-Июль_ план_факт.xlsx', 'Аренда. Площадки. ГМ МАГНИТ.xlsx', 'Ежедневная отчетность (планирование работы) РОП.docx', 'Заказы.xlsx', 'Отчеты Афипский.xlsx', 'Отчеты Белореченск1.xlsx', 'Отчеты Елизаветинская.xlsx', 'Отчеты Кореновск1.xlsx', 'Отчеты Кореновск2.xlsx', 'Отчеты Краснодар1.xlsx', 'Отчеты Краснодар2.xlsx', 'Отчеты Краснодар3.xlsx', 'Отчеты Майкоп1.xlsx', 'Рабочие документы для РО2.xlsx', 'РО2_ Основные задачи.docx', 'Статистика салонов.xlsx', 'Статистики РО2.xlsx', 'Техника продаж.docx', 'Чек-лист посещения салона.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Рабочие документы РО3
# ['ЗП']
# ['Форма для внесения данных о новом контрагенте.xlsm.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Рабочие документы РО3\ЗП
# ['ЗП ТТ']
# ['Архив ЗП ТТ.xlsx', 'ЗП АУП.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\Рабочие документы РО3\ЗП\ЗП ТТ
# []
# ['А-1.xlsx', 'Бел-1.xlsx', 'Елиз-1.xlsx', 'Кор-1.xlsx', 'Кор-2.xlsx', 'КРД-1.xlsx', 'КРД-2.xlsx', 'КРД-3.xlsx', 'Майкоп-1.xlsx']
#
#
# .\drive-download-20190126T214701Z-001\СЕРТИФИКАТ СООТВЕТСТВИЯ
# ['ЛИНЗЫ', 'МКЛ', 'ОПРАВЫ', 'Солнцезащитные очки']
# []
#
#
# .\drive-download-20190126T214701Z-001\СЕРТИФИКАТ СООТВЕТСТВИЯ\ЛИНЗЫ
# ['Эссилор']
# ['1.1.jpg', '1.2.jpg', '1.3.jpg', '1.4.jpg', 'Мульти Декларация.JPG', 'Мульти Приложение.JPG', 'Мульти Разрешение.JPG', 'Мульти Сертификат.JPG', 'Сертификат линзы ВЕК.pdf', 'Сертификат линзы.pdf']
#
#
# .\drive-download-20190126T214701Z-001\СЕРТИФИКАТ СООТВЕТСТВИЯ\ЛИНЗЫ\Эссилор
# []
# ['Декларация.PDF', 'Декларация1.PDF', 'Декларация2.PDF', 'Декларация3.PDF', 'Регист.удост..PDF', 'Регист.удост.1.PDF', 'Регистр.удост..PDF', 'Регистр.удостоверение.PDF', 'Сертифика.PDF', 'Сертификат+Приложение.PDF', 'Сертификат.PDF', 'Сертификат1.PDF']
#
#
# .\drive-download-20190126T214701Z-001\СЕРТИФИКАТ СООТВЕТСТВИЯ\МКЛ
# []
# ['1.1.jpg', '1.2.jpg', '1.3.jpg', '1.4.jpg', '1.5.jpg']
#
#
# .\drive-download-20190126T214701Z-001\СЕРТИФИКАТ СООТВЕТСТВИЯ\ОПРАВЫ
# []
# ['1.jpeg', '2.jpeg', '3.jpg', '4.jpg', '5.jpg', '6.jpg']
#
#
# .\drive-download-20190126T214701Z-001\СЕРТИФИКАТ СООТВЕТСТВИЯ\Солнцезащитные очки
# []
# ['1.jpg', '2.jpg', 'Солнцезащитные.pdf']
#
#
# .\drive-download-20190126T214701Z-001\Справочные материалы
# []
# ['2015-02-28 Программа передачи функций.docx', '2015-03-22 Памятка _Формулы состояний__.docx', '2018-10-08 Программа формирования должностных папок.docx', '4 вида продукта продукт 1-4.pdf', 'Алгоритм проведения диагностики зрения для любого клиента.docx', 'Алгоритм работы с мультифокальными линзами.docx', 'Бифокальные и прогрессивные линзы.docx', 'Инструкция для определения подлинности купюр.docx', 'Инструкция по прояснению продукта должности.pdf', 'Инструкция по составлению задания для ориентации.pdf', 'Как выполнять упражнение вопрос-ответ(для тренера).docx', 'КНИГА ЗНАНИЙ 28.08.17(1).docx', 'КНИГА ЗНАНИЙ 28.08.17.docx', 'Корпоративный словарь - вноси сюда любое непонятое слово.docx', 'ОПРЕДЕЛЕНИЯ ОСНОВНЫХ ПОНЯТИЙ “ПРОДУКТ И ВИДЫ ОБМЕНА”.docx', 'Памятка _Формулы состояний_.docx', 'Пример описания обязанностей должности.pdf', 'Составление плана для нового сотрудника.pdf', 'Формулы состояний.docx']
#
#
# .\drive-download-20190126T214701Z-001\ФП
# []
# ['2015-12-22 Приказ о проведении первого ФП (пример).docx']
#
#
# .\HR
# ['Анкеты', 'Лист адаптации', 'Мир Дверей Книга знаний-20200511T132103Z-001', 'Обязательство о неразгл.тайны', 'Оптика', 'Перформия бланки', 'Распоряжения и регламенты отдела персонала', 'Регламент планирования и оплаты рабочего времени', 'Регламент проведения утренней планерки', 'Стандарты [Ёха]', 'Стандарты Голый повар', 'Юг-Авто']
# ['123.PNG', '1234.PNG', '2018-2019.xlsx', 'dolzhnostnaya_instruktsiya_menedzhera_po_personalu.zip', 'HR-платформы.xlsx', 'Programma_adaptatsii_SUG.xlsx', 'WT JetRuby.pptx', 'Анкета ГК Юг-Авто.pdf', 'Анкета увольняющегося сотрудника.docx', 'Бланк организации.docx', 'Вакансия _Курьер_.xlsx', 'Воронка по подбору hh 2019.xlsx', 'Воронка по подбору.xlsx', 'ГСМ.xlsx', 'История Компании.pdf', 'Календарь ДР.xlsx', 'Контакты.xlsx', 'Копия Подбор персонала - факт.xlsx', 'Кореновск - отработаны.xlsx', 'Налоги и взносы (кратко).pdf', 'Описание вакансии _Экономист-финансист_.docx', 'ПАПКА ШТАТНОГО СОТРУДНИКА образец.docx', 'План продаж.xlsx', 'Помощник Генерального директора по PR.docx', 'Правила общения по телефону с соискателями.docx', 'Прайс пакеты 17.02.18 (для печати).xlsx', 'Приведи друга в компанию.jpg', 'Причины увольнений.xlsx', 'Рабочий хронометраж.xlsx', 'Размещение вакансий.xlsx', 'Реестр ИП для ПО.xlsx', 'РО1 планирование работы менеджера по персоналу.xlsx', 'Список кандидатов.xlsx', 'Список ТМЦ для кофейни.xlsx', 'Таблица продаж.xls', 'Таблица сотрудников.xls.xlsx', 'Тестовые задания товаровед.xlsx', "Треннинг бариста 2015  Traveller's Coffee.docx"]
#
#
# .\HR\Анкеты
# []
# ['Анкета Ёха.doc', 'Анкета Голый повар.doc']
#
#
# .\HR\Лист адаптации
# []
# ['Лист Адаптации Ёха.doc', 'Лист Адаптации ГП.doc']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001
# ['Portalle -20200513T052214Z-001', 'Мир Дверей Книга знаний']
# ['Видео про обман покупателя.docx', 'ТЗ сайт.docx']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001
# ['Portalle ']
# []
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle
# ['Electra', 'Shweda ', 'Shweda light', 'Инфа о новинках', 'Контент для онлайн', 'Обучение по Битрикс24']
# ['IP видео панель инструкция.pdf', 'Версия в печать 18.07.2019. каталог.pdf', 'ВидеоДомофон сенсорный инструкция.pdf', 'Выездной менеджер.docx', 'Инструкция для мобильного приложения.pdf', 'Новая CRM система от15 01 20 в 11-40.pdf', 'Паспорт двери Portalle.pdf', 'СДО POrtalle Smart.pdf', 'Файл_001(1).png', 'Файл_001.png']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle \Electra
# []
# ['Electra 1.pdf']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle \Shweda
# []
# ['Shweda (1).pdf']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle \Shweda light
# []
# ['Shweda Light (1).pdf']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle \Инфа о новинках
# []
# []
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle \Контент для онлайн
# []
# ['Ролик об изготовлении Панелей Collori.mp4']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Portalle -20200513T052214Z-001\Portalle \Обучение по Битрикс24
# []
# ['4b58429d-d9dd-492a-b691-e629b2c60c3b.MP4', '5f476c5a-acf9-40b8-bbaf-1f6ec381b7bf.MP4', 'c40fc793-e7fc-4125-a135-3aef731cb37b.MP4', 'Регламент  ведения сделки для сотрудника Салона.pdf']
#
#
# .\HR\Мир Дверей Книга знаний-20200511T132103Z-001\Мир Дверей Книга знаний
# []
# ['Бизнес-процессы и регламент Мир дверей основной 1.pdf', 'Должностная инструкция менеджера по продажам.docx', 'Еженедельный отчет.xlsx', 'Книга знаний.doc', 'Отчет ежедневный.xlsx', 'План продаж МД.xlsx', 'Приказ № 2 о сроках поставки.doc', 'Приказ № 6 о скидках от 15 07 19г.doc', 'Приказ № 8 о мотивации от 09 01 20г.doc', 'Проект должностной инструкции операционного директора.DOCX', 'Рабочая тетрадь - дневник адаптации.docx', 'Реквизиты.docx']
#
#
# .\HR\Обязательство о неразгл.тайны
# ['Обязательство на Ёха', 'Обязательство на ГП']
# []
#
#
# .\HR\Обязательство о неразгл.тайны\Обязательство на Ёха
# []
# ['Обяз-во о неразгл. коммерч. тайны - Ёха ООО Альдахлеб.doc']
#
#
# .\HR\Обязательство о неразгл.тайны\Обязательство на ГП
# []
# ['Обяз-во о неразгл. коммерч. тайны - ГП ООО Альдахлеб.doc']
#
#
# .\HR\Оптика
# ['Аналитика', 'Всячина', 'Графики работы', 'Документооборот', 'ЗРС,ЗВС, планы, доклады', 'Описание работы Отделения Построения', 'Рабочие документы для РО2', 'Рабочие документы РО3', 'СЕРТИФИКАТ СООТВЕТСТВИЯ', 'Справочные материалы', 'ФП']
# ['2016-01-23 Программа подготовки к собранию персонала для ведущего.docx', '2016-01-23 Программа подготовки к собранию персонала для остальных РО.docx', '2016-01-23 Программа подготовки к собранию персонала для РО1.docx', '2018-09-27 Инструкция по формированию должностных папок.docx', 'movavi-screen-capture-studio-9.5.0-repack.zip', 'Описание работы Отделения Построения.rar', 'Пароли ро1.xlsx', 'Распорядок дня менеджера по персоналу.docx', 'РО1 Технология описания должности.docx', 'Томила АМПП.xlsx', 'Учет движения книг в компании.xlsx', 'Чек-лист посещения салона.xlsx']
#
#
# .\HR\Оптика\Аналитика
# []
# ['Планфакт месяц по подразделениям.xlsx', 'Планфакт недельный.xlsx', 'ФОТ.xlsx', 'Эффективность 07.2018.xlsx', 'Эффективность.xlsx']
#
#
# .\HR\Оптика\Всячина
# ['Архив АА', 'ГСМ', 'Игра по ФП', 'Координации', 'ОДО ФОТООТЧЕТЫ ']
# ['ilovepdf_com-1-6.pdf', 'ilovepdf_com-11-16.pdf', 'ilovepdf_com-16-21.pdf', 'ilovepdf_com-21-27.pdf', 'ilovepdf_com-6-11.pdf', 'Апрель Ежедневные отчеты.xlsx', 'Вакансия _Курьер_.xlsx', 'ГСМ курьер.xlsx', 'ГСМ.xlsx', 'ДР.xlsx', 'Запись Елизаветинская.mp4', 'Копия прайс пакеты 01.06.18.xlsx', 'План продаж.xlsx', 'Ппф Приемная.m4a', 'презентация отчет Итоги за 2018 год.pptx', 'Статья_ _Как передать функцию_.docx']
#
#
# .\HR\Оптика\Всячина\Архив АА
# ['Архив', 'Картинки для карты линз', 'Лед строка']
# ...
# ['Сканы']
# ['Бухгалтерия.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Бухгалтерия\Сканы
# []
# ['Гуднина Елена Викторовна.pdf', 'Яцкова Светлана Александровна.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Вахта
# []
# ['Брызгалин Роман.pdf', 'Латкин Андрей.pdf', 'Худяков Олег.pdf', 'Черник Мария.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Инженерно-техническая служба
# []
# ['Инженерно-техническая служба.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Колл-центр
# ['Сканы']
# ['Колл-центр.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Колл-центр\Сканы
# []
# ['Володкин Юрий Вячеславович.pdf', 'Попова Карина Сергеевна.pdf', 'Шпанько Ирина Андреевна.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Логистика и обеспечение
# ['Сканы']
# ['Логистика и обеспечение.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Логистика и обеспечение\Сканы
# []
# ['Худяков Олег.pdf', 'Ярыгин Алексей.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Майкоп
# ['Сканы']
# ['Лада Майкоп.xlsx', 'Мультибренд Майкоп.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Майкоп\Сканы
# []
# ['Бахов Алий.pdf', 'Бжемухов Аскер.pdf', 'Гучетль Арсен Муратович.pdf', 'Дзеухожев Хасан Исхакович.pdf', 'Долев Амин Аскерович.pdf', 'Крутов Александр.pdf', 'Лашков Александр Павлович.pdf', 'Сокуров Арсен.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Отдел корпоративных продаж
# ['Сканы']
# ['Корпораты.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Отдел корпоративных продаж\Сканы
# []
# ['Воротников Владислав Георгиевич.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Подразделение F_I
# ['Сканы']
# ['Подразделение F_I.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Подразделение F_I\Сканы
# []
# ['Бондаренко Марина Андреевна.pdf', 'Вихляева Вероника Юрьевна.pdf', 'Елькина Светлана Сергеевна.pdf', 'Колесникова Елена Николаевна.pdf', 'Мамонтова Алена Васильевна.pdf', 'Рязанцев Дмитрий Сергеевич.pdf', 'Снисаренко Галина Григорьевна.pdf', 'Сухорукова Светлана Маратовна.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Регламент
# ['Сканы']
# ['Регламент.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Регламент\Сканы
# []
# ['Власенко Василий Николаевич.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Сервис-Люкс
# ['Сканы']
# ['Сервис-Люкс Дзержинского.xlsx', 'Сервис-Люкс Яблоновский.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Сервис-Люкс\Сканы
# []
# ['Кущев Вадим.pdf', 'Трипольский Виталий Олегович.pdf', 'Щербаков Алексей Владимирович.pdf']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Служба безопасности Холдинга
# []
# ['Служба Безопасности Холдинга.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\Управляющая компания
# ['Сканы']
# ['Управляющая компания.xlsx']
#
#
# .\HR\Юг-Авто\Югавка\Отдел по работе с персоналом\Увольнения\
# ['Desktop.zip', 'status.xlsx', '~$сьмо первого выхода - стало.docx', 'Анализ отвалов.docx', 'Анкета KHMarketing.pdf', 'Вводное письмо - было.docx', 'Вводное письмо - стало.docx', 'Инструкция по размещению вакансий на площадке hh.docx', 'Инструкция по созданию отчета по открытым вакансиям.docx', 'история статусов вакансий.xlsx', 'Опросник увольняющегося - длинный.docx', 'Опросник увольняющегося - короткий.docx', 'Отвалы 1.xlsx', 'Отчет по hh 2020.xlsx', 'Отчет по воронке 01.06.xlsx', 'отчет по воронке общедоступный с 22.04.xlsx', 'Перечень регламентов.xlsx', 'Письмо первого выхода - было.docx', 'Письмо первого выхода - стало.docx', 'Причины увольнений 2019-2020.xlsx', 'Причины увольнений на редактуру.xlsx', 'Проблемы ОП.xlsx', 'Скрипт входящего звонка.docx', 'Стандарт по разбору откликов на площадке hh.docx', 'Стандарт работы с новыми вакансиями.docx', 'Стандарт работы с повторно открытыми вакансиями.docx', 'Стандарт работы с размещенными вакансиями на hh.ru.docx', 'Статистика по менеджерам с hh.ru 01.01-31.03.xlsx', 'Хронометраж сотрудника ОП.xlsx', 'Шаблон для рассылки.docx']
#
#
# .\Python
# ['.ipynb_checkpoints']
# ['Untitled.ipynb']
#
#
# .\Python\.ipynb_checkpoints
# []
# ['Untitled-checkpoint.ipynb']
#
#
# .\Setup
# ['AMD', 'Monero', 'NVIDIA']
# []
#
#
# .\Setup\AMD
# ['logs']
# ['beam-pool.bat', 'btg-pool.bat', 'clo-pool.bat', 'erg-pool.bat', 'etc-pool.bat', 'eth-pool.bat', 'etp-pool.bat', 'exp-pool.bat', 'firo-pool.bat', 'flux-pool.bat', 'grin-pool.bat', 'lolMiner.exe', 'mwc-pool.bat', 'rvn-pool.bat', 'teamredminer.exe', 'windows_tdr_fix.reg']
#
#
# .\Setup\AMD\logs
# []
# []
#
#
# .\Setup\Monero
# []
# ['WinRing0x64.sys', 'xmr-pool.bat', 'xmrig.exe']
#
#
# .\Setup\NVIDIA
# ['NVIDIA_1080_ONLY', 'NVIDIA_LHR_GPU_ONLY']
# ['ae-pool.bat', 'beam-pool.bat', 'btg-pool.bat', 'clo-pool.bat', 'ctxc-pool.bat', 'erg-pool.bat', 'etc-pool.bat', 'eth-pool.bat', 'etp-pool.bat', 'exp-pool.bat', 'firo-pool.bat', 'flux-pool.bat', 'grin-pool.bat', 'miner.exe', 'mwc-pool.bat', 'rvn-pool.bat', 't-rex.exe']
#
#
# .\Setup\NVIDIA\NVIDIA_1080_ONLY
# []
# ['eth-pool.bat']
#
#
# .\Setup\NVIDIA\NVIDIA_LHR_GPU_ONLY
# []
# ['eth-ergo-dual-mining.bat', 'eth-pool.bat', 'eth-rvn-dual-mining.bat']
#
#
# .\thphn163
# ['HwProfiles']
# ['Backups.bdb', 'Help needed.txt', 'Known issues.txt', 'libeay32.dll', 'READFIRST.txt', 'ssleay32.dll', 'Thaiphoon.exe', 'THPConfig.ini', 'Version.txt']
#
#
# .\thphn163\HwProfiles
# []
# ['Gigabyte B450 Aorus Elite.hwp', 'Gigabyte GA-E350N.hwp', 'Gigabyte GA-H87N-WiFi.hwp', 'Gigabyte H61M-S1.hwp', 'Gigabyte X79-UD3.hwp']
#
#
# .\Victoria528
# ['Help', 'LNG', 'LOGS']
# ['porttalk.sys', 'USB_SupportList.rtf', 'Victoria.exe', 'Victoria.ini']
#
#
# .\Victoria528\Help
# ['English', 'Ukraine', 'Русский']
# []
#
#
# .\Victoria528\Help\English
# []
# ['dcomemo.rtf', 'vichlp.rtf', 'whatsnew.rtf']
#
#
# .\Victoria528\Help\Ukraine
# []
# ['dcomemo.rtf', 'vichlp.rtf', 'whatsnew.rtf']
#
#
# .\Victoria528\Help\Русский
# []
# ['dcomemo.rtf', 'vichlp.rtf', 'whatsnew.rtf']
#
#
# .\Victoria528\LNG
# []
# ['English.lng', 'Ukraine.lng', 'Русский.lng']
#
#
# .\Victoria528\LOGS
# ['KINGSTON SV300S37A120G__50026B724900A48E', 'WDC WD10EZEX-19M2NA0__WD-WCC3FNNJ10LD']
# ['eventlog.txt']
#
#
# .\Victoria528\LOGS\KINGSTON SV300S37A120G__50026B724900A48E
# []
# ['bads_KINGSTON SV300S37A120G_50026B724900A48E.txt', 'eventlog.txt', 'Passp_KINGSTON SV300S37A120G_50026B724900A48E.bin', 'SMART_KINGSTON SV300S37A120G_50026B724900A48E.bin', 'SMBASE_KINGSTON SV300S37A120G_50026B724900A48E.bin']
#
#
# .\Victoria528\LOGS\WDC WD10EZEX-19M2NA0__WD-WCC3FNNJ10LD
# []
# ['bads_WDC WD10EZEX-19M2NA0_WD-WCC3FNNJ10LD.txt', 'eventlog.txt', 'Passp_WDC WD10EZEX-19M2NA0_WD-WCC3FNNJ10LD.bin', 'SMART_WDC WD10EZEX-19M2NA0_WD-WCC3FNNJ10LD.bin', 'SMBASE_WDC WD10EZEX-19M2NA0_WD-WCC3FNNJ10LD.bin']
#
#
# .\_17e8313e80520da7c04cfe8307d468f1_vector_operations
# ['.ipynb_checkpoints']
# ['vector_operations.ipynb']
#
#
# .\_17e8313e80520da7c04cfe8307d468f1_vector_operations\.ipynb_checkpoints
# []
# ['vector_operations-checkpoint.ipynb']
#
#
# .\Архив (2)
# []
# ['Кассир.jpg', 'ПК.jpg', 'Работник магазина.jpg', 'РТЗ.jpg', 'Сотрудник магазина.jpg']
#
#
# .\Казань
# []
# ['Алиева Елена.pdf', 'Белоусов Антон Егорович.pdf', 'Булатов Рафаэль.pdf', 'Бурнаев Данил.pdf', 'Гарифуллин Радик.pdf', 'Гафурова Анастасия Геннадьевна.pdf', 'Гуляев Максим Андреевич.pdf', 'Завьялова Екатерина Антоновна.pdf', 'Замалтдинова Гульнара.pdf', 'Зиннатуллина Эльвирочка.pdf', 'Мерлинкин Илья.pdf', 'Павлов Дмитрий.pdf', 'Паранин Дмитрий.pdf', 'Рахимов Евгений.pdf', 'Рогова Илина.pdf', 'Чайников Дмитрий Викторович.pdf', 'Шафиков Нияз.pdf']
#
#
# .\Статистика по подбору
# ['Отчет по вакансиям hh.ru']
# ['Воронка по подбору hh 2018(новая) .xlsx', 'Воронка по подбору hh 2018.xlsx', 'Воронка по подбору hh 2019(новая).xlsx', 'Воронка по подбору hh 2019.xlsx', 'Воронка по подбору Активный поиск 2018.xlsx', 'Воронка по подбору Активный поиск 2019 (yjdfz).xlsx', 'Воронка по подбору Активный поиск 2019.xlsx', 'Клиентская база.xlsx', 'Конверсия по первичным собеседованиям (дни недели) 2018.xlsx', 'Конверсия по первичным собеседованиям (дни недели) 2019.xlsx', 'Март.xlsx', 'Направления на работу 2013-2019.xlsx', 'Отказы СБ.xlsx', 'Отчет по отказам 2018-2019.xlsx', 'Подбор 2017-2019.xlsx', 'Просмотры и отклики hh.ru по дням недели 2018.xlsx', 'Просмотры и отклики hh.ru по дням недели 2019.xlsx', 'Результаты работы за полгода.xlsx', 'Увольнения 2018-2019.xlsx', 'Янв-Фев.xlsx']
#
#
# .\Статистика по подбору\Отчет по вакансиям hh.ru
# []
# ['Отчет по hh 2018.xlsx', 'Отчет по hh 2019.xlsx']
#
#
# .\Творчество
# ['Аудио - Стёпкина', 'Диктофон']
# ['Dokument.docx', 'Dokument_1.docx', 'Odin_sploshnoy_reportazh.docx', 'А чего вы хотели.docx', 'Диалоги о вечном.docx', 'Документ 1.docx', 'Переписка ВК.docx', 'Посыл.m4a', 'Философия.txt']
#
#
# .\Творчество\Аудио - Стёпкина
# []
# ['20161204-023829.mp3', '20161204-025626.mp3', '20161204-025751.mp3', '20161204-031029.mp3', '20161204-032210.mp3']
#
#
# .\Творчество\Диктофон
# ['Pfgbcb', 'Диктофон']
# ['20161204 023829.m4a', '20161204 025626.m4a', '20161204 025751.m4a', '20161204 031029.m4a', '20161204 032210.m4a']
#
#
# .\Творчество\Диктофон\Pfgbcb
# []
# ['20161204-023829.mp3', '20161204-025626.mp3', '20161204-025751.mp3', '20161204-031029.mp3', '20161204-032210.mp3', 'Pfgbcb.7z']
#
#
# .\Творчество\Диктофон\Диктофон
# ['20140509 180509.composition', '20150409 173339.composition', '20150712 134927.composition', '20150916 133749.composition', '20150929 141732.composition', '20151031 215533.composition', '20160229 065008.composition', '20160308 014905.composition', '20160308 015129.composition', '20160308 015348.composition', '20160418 222457.composition', '20160822 161817.composition', '20161204 023829.composition', '20161204 025626.composition', '20161204 025751.composition', '20161204 031029.composition', '20161204 032210.composition', 'Sync']
# ['20140509 180509.m4a', '20140509 180509.waveform', '20150409 173339.m4a', '20150409 173339.waveform', '20150712 134927.m4a', '20150712 134927.waveform', '20150916 133749.m4a', '20150916 133749.waveform', '20150929 141732.m4a', '20150929 141732.waveform', '20151031 215533.m4a', '20151031 215533.waveform', '20160229 065008.m4a', '20160229 065008.waveform', '20160308 014905.m4a', '20160308 014905.waveform', '20160308 015129.m4a', '20160308 015129.waveform', '20160308 015348.m4a', '20160308 015348.waveform', '20160418 222457.m4a', '20160418 222457.waveform', '20160822 161817.m4a', '20160822 161817.waveform', '20161204 023829.waveform', '20161204 025626.waveform', '20161204 025751.waveform', '20161204 031029.waveform', '20161204 032210.waveform', 'AssetManifest.plist', 'CustomLabels.plist', 'Recordings.db', 'Recordings.db-shm', 'Recordings.db-wal', 'SyncAnchor.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20140509 180509.composition
# []
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20150409 173339.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20150409 173339.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20150712 134927.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20150712 134927.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20150916 133749.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20150916 133749.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20150929 141732.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20150929 141732.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20151031 215533.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20151031 215533.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20160229 065008.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20160229 065008.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20160308 014905.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20160308 014905.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20160308 015129.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20160308 015129.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20160308 015348.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20160308 015348.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20160418 222457.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20160418 222457.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20160822 161817.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20160822 161817.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20161204 023829.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20161204 023829.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20161204 025626.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20161204 025626.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20161204 025751.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20161204 025751.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20161204 031029.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20161204 031029.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\20161204 032210.composition
# ['fragments']
# ['manifest.plist']
#
#
# .\Творчество\Диктофон\Диктофон\20161204 032210.composition\fragments
# []
# []
#
#
# .\Творчество\Диктофон\Диктофон\Sync
# []
# []

# %% [markdown]
# ## Библиотека shutil и копирование файлов

# %% [markdown]
# Библиотека os предлагает набор инструментов для работы с файлами

# %% [markdown]
# ### copy('откуда_копируем/что_копируем', 'куда_копируем/как_обзовем_копию')

# %% [markdown]
# __copy()__ библиотеки shutil позволяет копировать целые файлы:

# %%
import shutil

# %%
shutil.copy('C:\\Users\\Пользователь\\Desktop\\Кассир.txt','C:\\Users\\Пользователь\\Конспекты\\КассирШутил.txt')
# Out:
# 'C:\\Users\\Пользователь\\Конспекты\\КассирШутил.txt'

# %%
shutil.copy('C:\\Users\\Пользователь\\Desktop\\525.jpg','C:\\Users\\Пользователь\\Конспекты\\Shutil.jpg')
# Out:
# 'C:\\Users\\Пользователь\\Конспекты\\Shutil.jpg'

# %%
print(os.urandom(5))
# Out:
# b'\xefGn\xcf\xcd'
